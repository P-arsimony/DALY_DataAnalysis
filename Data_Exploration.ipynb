# %% [markdown]
# # Conjunto de datos.
# El conjunto principal de datos proviene de la Organización Mundial de la Salud (OMS)[https://www.who.int/data/gho/data/themes/mortality-and-global-health-estimates/global-health-estimates-leading-causes-of-dalys/] [^1]. Los DALYs (*Disability-adjusted life years*) se reportan a tres escalas diferentes: global, regional y a nivel de país. Para este análisis nos interesa, por el momento, los datos reportados a nivel global desde 2000-2021 de los cuales sólo hay datos para los años 2000, 2010, 2015, 2019, 2020 y 2021 (que se debe a que estimados anteriores no se pueden comparar con los actuales).
#
# Al descargar el archivo ghe2021_daly_whoregion_new.xlsx fue movido a la subcarpeta data_raw. Debe contener

# %% [markdown]
# # Cargar datos.

# %%
# !pip install pandas openpyxl

import pandas as pd
filename = 'data_raw/DALYs/ghe2021_daly_global_new.xlsx'
df = pd.read_excel(filename)
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      Unnamed: 0 Unnamed: 1                                     Unnamed: 2
# 0           NaN        NaN   GLOBAL HEALTH ESTIMATES 2021 SUMMARY TABLES:
# 1           NaN        NaN  GLOBAL DALYs BY CAUSE, AGE AND SEX, 2000-2021
# 2           NaN        NaN                                            NaN
# 3           NaN        NaN                                      July 2024
# 4           NaN        NaN                                            NaN
# ..          ...        ...                                            ...
# 199         NaN        NaN             Venezuela (Bolivarian Republic of)
# 200         NaN        NaN                                       Viet Nam
# 201         NaN        NaN                                          Yemen
# 202         NaN        NaN                                         Zambia
# 203         NaN        NaN                                       Zimbabwe
#
# ...

# %% [markdown]
# # Abrir en Google Colab.

# %%
# Sincronizar google drive con Colab
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Especificar la ubicación del archivo
filename = '/content/drive/My Drive/DALY_DataAnalysis/data_raw/DALYs/ghe2021_daly_global_new.xlsx'

# Abrir archivo con pandas
df = pd.read_excel(filename)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Sincronizar google drive con Colab
#       2 import pandas as pd
# ----> 3 from google.colab import drive
#       4 drive.mount('/content/drive')
#       6 # Especificar la ubicación del archivo
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# Lectura de hoja "Global 2021"
G2021= pd.read_excel(filename, sheet_name="Global 2021")
G2021
# Lectura de hoja "Global 2020"
G2020 = pd.read_excel(filename, sheet_name="Global 2020")
G2020
# Lectura de hoja "Global 2019"
G2019 = pd.read_excel(filename, sheet_name="Global 2019")
G2019
# Lectura de hoja "Global 2015"
G2015 = pd.read_excel(filename, sheet_name="Global 2015")
G2015
# Lectura de hoja "Global 2010"
G2010 = pd.read_excel(filename, sheet_name="Global 2010")
G2010
# Lectura de hoja "Global 2000"
G2000 = pd.read_excel(filename, sheet_name="Global 2000")
G2000
# Out:
#     Global Health Estimates 2021: DALYs by age, sex and cause Unnamed: 1  \
# 0                                                  NaN               NaN
# 1                                              Region:               NaN
# 2                                                Year:               NaN
# 3                                                  NaN               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 218                                               1600               NaN
# 219                                               1610               NaN
# 220                                               1620               NaN
# 221                                               1630               NaN
# 222                                               1700               NaN
#
#     Unnamed: 2                                Unnamed: 3  \
# ...

# %%
df.columns
# Out:
# Index(['Global Health Estimates 2021: DALYs by age, sex and cause',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %% [markdown]
# # Exploración Básica con *Profiles*.

# %%
# !pip install ydata_profiling

from ydata_profiling import ProfileReport

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2021_profiles.html"
prof = ProfileReport( G2021, title="Global 2021 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2020_profiles.html"
prof = ProfileReport( G2020, title="Global 2020 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2019_profiles.html"
prof = ProfileReport( G2019, title="Global 2019 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2015_profiles.html"
prof = ProfileReport( G2015, title="Global 2015 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2010_profiles.html"
prof = ProfileReport( G2010, title="Global 2010 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

file_profile = "/content/drive/My Drive/DALY_DataAnalysis/profiles/Global2000_profiles.html"
prof = ProfileReport( G2000, title="Global 2000 DALYs Profile", explorative=True)
prof.to_file(output_file=file_profile)

# %% [markdown]
# # Ajustes al reporte.

# %% [markdown]
# # Referencias.
# [^1]: Global Health Estimates 2021: Disease burden by Cause, Age, Sex, by Country and by Region, 2000-2021. Geneva, World Health Organization; 2024.
